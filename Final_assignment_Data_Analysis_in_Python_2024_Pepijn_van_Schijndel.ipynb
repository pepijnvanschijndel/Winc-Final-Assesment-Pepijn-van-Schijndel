# %% [markdown]
# <a href="https://colab.research.google.com/github/pepijnvanschijndel/Winc-Final-Assesment-Pepijn-van-Schijndel/blob/main/Final_assignment_Data_Analysis_in_Python_2024_Pepijn_van_Schijndel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final assigment
#
#
# 1.   Biggest predictor of CO2 output
# 2.   Biggest strides in decreasing CO2 output
# 3. Best future price for non-fossil fuel energy

# %% [markdown]
# ## Requirements
# * You need to present a report solving the questions and the code that you used (more on that later)
# * The report (so the code), must include 3 graphs, one for every question.
# * Use functions for dataframes, don't create them yourself. Use Pandas for that.
# * Load the data from the repositories using the raw link if possible.
# * Use Pandas functions to substract column names and filter the data
# * Use as much as generic coding as possible
# * Use .copy() to prevent warnings generated by Pandas or to avoid affecting the original DataFrame.
# * Add titles, labels and legends to the figures
# * Your code should not raise errors

# %% [markdown]
# ## Final assignment - 1. Biggest predictor of CO2 output.ipynb
#
# What is the biggest predictor of a large CO2 output per capita of a country?

# %% [markdown]
# ### Guideline
# To determine this you may want to consider things like GDP per capita, diets, number of cars per capita, various energy source, mobility and other factors.
#
# Your answer can also be a specific combination of certain factors. Anyway, remember to include the explanations in your report.

# %% [markdown]
# ### Step 1 Research

# %% [markdown]
# Start by going to ["Our World in Data" webpage](https://ourworldindata.org/) and feel free to use any dataset that you can find.

# %% [markdown]
# The biggest predictor of a large CO2 output per capita of a country can vary depending on numerous factors such as economic structure, industrialization level, energy sources, government policies, and cultural practices.
#
# In this research I will compare CO2 ouput per capita to the following
#
# 1. **Economic Development**: In what way the GDP correlates to CO2 emissions per capita?
#
# 2. **Energy Consumption and Sources**: Does decreasing the use of fossil fuels such as coal, oil, and natural gas and increasing renewable energy sources like wind, solar, and hydroelectric power for energy production per capita decrease CO2 emissions?
#
# 3. **Education**: What influence has educating people on CO2 emissions per capita?
#
# 4. **Diet**: Is there a connection between calories per day and the CO2 emissions per capita? especially standards are to low or to high?
#
# It's important to note that these factors often interact with each other, and the relative importance of each factor can vary depending on the specific context of a country. Additionally, other social, political, and geographical factors may also play a role in CO2 emissions per capita.

# %% [markdown]
# ### Step 2 Define data
# All data per capita of a country from the ["Our World in Data" webpage](https://ourworldindata.org/)
#
# #### Population
# What is the density of the population in surface per capita of a country?
#
# **File**
#
# population-and-demography.csv
#
# **Source population**
#
# United Nations, World Population Prospects (2022) – processed by Our World in Data. “Population” [dataset]. United Nations, World Population Prospects (2022) [original data].
#
# #### CO2 Emission
# What is the CO2 emission per capita of a country?
#
# **File**
#
# co-emissions-per-capita.csv
#
# **Source CO2 emissions per capita**
#
# Global Carbon Budget (2023); Population based on various sources (2023) – with major processing by Our World in Data. “Annual CO₂ emissions (per capita) – GCB” [dataset]. Global Carbon Project, “Global Carbon Budget”; Various sources, “Population” [original data].
#
# #### Economic development
# What is the GDP per capita of a country?
#
# **File**
# gdp-per-capita-maddison.csv
#
# **Source GDP per capita**
#
# Bolt and van Zanden - Maddison Project Database 2023 – with minor processing by Our World in Data. “GDP per capita – Maddison Project Database – Historical data” [dataset]. Bolt and van Zanden, “Maddison Project Database 2023” [original data]. Retrieved June 9, 2024 from https://ourworldindata.org/grapher/gdp-per-capita-maddison
#
# #### Energy Consumption and Sources
# What is the fossil fuel consumption per capita of a country? What is the consumption of renewable energy sources like wind, solar, and hydroelectric power for energy production per capita of a country?
#
# **Files**
#
# * per-capita-energy-use.csv
# * fossil-fuels-per-capita.csv
# * modern-renewable-energy-consumption.csv
#
# **Source energy consumption per capita**
#
# U.S. Energy Information Administration (2023); Energy Institute - Statistical Review of World Energy (2023); Population based on various sources (2023) – with major processing by Our World in Data. “Primary energy consumption per capita” [dataset]. U.S. Energy Information Administration, “International Energy Data”; Energy Institute, “Statistical Review of World Energy”; Various sources, “Population” [original data].
#
# **Source fossil fuel per capita**
#
# Energy Institute - Statistical Review of World Energy (2023); Population based on various sources (2023) – with major processing by Our World in Data. “Fossil fuel consumption per capita” [dataset]. Energy Institute, “Statistical Review of World Energy”; Various sources, “Population” [original data].
#
# **Source renewable energy per capita**
#
# Energy Institute - Statistical Review of World Energy (2023) – with major processing by Our World in Data. “Electricity generation from hydropower” [dataset]. Energy Institute, “Statistical Review of World Energy” [original data].
#
# #### Education
# What is the time spent in school for a capita of a country?
#
# **File**
# mean-years-of-schooling-long-run.csv
#
# **Source schooling per capita**
# Barro and Lee (2015); Lee and Lee (2016) – with major processing by Our World in Data. “Average years of schooling” [dataset]. Barro and Lee, “Projections of Educational Attainment”; Lee and Lee, “Human Capital in the Long Run” [original data].
#
# #### Diet
# How much caloric supply does every capita per country have?
#
# **File**
# daily-per-capita-caloric-supply.csv
#
# **Source daily caloric supply per capita**
# Food and Agriculture Organization of the United Nations (2023); Harris et al. (2015); Floud et al. (2011); Jonsson (1998); Grigg (1995); Fogel (2004); Food and Agriculture Organization of the United Nations (2000); Food and Agriculture Organization of the United Nations (1949); USDA Economic Research Service (ERS) (2015) – with major processing by Our World in Data. “Daily calorie supply per person” [dataset]. Food and Agriculture Organization of the United Nations, “Food Balances: Food Balances (-2013, old methodology and population)”; Food and Agriculture Organization of the United Nations, “Food Balances: Food Balances (2010-)”; Harris et al., “How Many Calories? Food Availability in England and Wales in the Eighteenth and Nineteenth Centuries”; Floud et al., “The Changing Body”; Jonsson, “Changes in food consumption in Iceland, 1770-1940”; Grigg, “The nutritional transition in Western Europe”; Fogel, “The Escape from Hunger and Premature Death”; Food and Agriculture Organization of the United Nations, “The State of Food and Agriculture 2000”; Food and Agriculture Organization of the United Nations, “The State of Food and Agriculture 1949”; USDA Economic Research Service (ERS), “U.S. food supply:  Nutrients and other food components, per capita per day” [original data].

# %% [markdown]
# ### Step 3 Ingest data

# %%
import pandas as pd
import numpy as np

# Ingesting data with pandas
df_population = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/population-and-demography.csv')
df_co2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/co-emissions-per-capita.csv')
df_gdp = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/gdp-per-capita-maddison.csv')
df_energy = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/per-capita-energy-use.csv')
df_fossil_energy = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/fossil-fuels-per-capita.csv')
df_renewable_energy = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/modern-renewable-energy-consumption.csv')
df_education = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/mean-years-of-schooling-long-run.csv')
df_diet = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/daily-per-capita-caloric-supply.csv')

# Check columns
display(df_population.head())
display(df_co2.head())
display(df_gdp.head())
display(df_energy.head())
display(df_fossil_energy.head())
display(df_renewable_energy.head())
display(df_education.head())
display(df_diet.head())
# Out:
#   Country name  Year  Population  Population of children under the age of 1  \
# 0  Afghanistan  1950     7480464                                   301735.0
# 1  Afghanistan  1951     7571542                                   299368.0
# 2  Afghanistan  1952     7667534                                   305393.0
# 3  Afghanistan  1953     7764549                                   311574.0
# 4  Afghanistan  1954     7864289                                   317584.0
#
#    Population of children under the age of 5  \
# 0                                    1248282
# 1                                    1246857
# 2                                    1248220
# 3                                    1254725
# 4                                    1267817
#
#    Population of children under the age of 15  Population under the age of 25  \
# 0                                     3068855                         4494349
# ...

# %% [markdown]
# ### Step 4 Match data

# %%
# Make copies of the original dataframes
df_population_copy = df_population.copy()
df_co2_copy = df_co2.copy()
df_gdp_copy = df_gdp.copy()
df_energy_copy = df_energy.copy()
df_fossil_energy_copy = df_fossil_energy.copy()
df_renewable_energy_copy = df_renewable_energy.copy()
df_education_copy = df_education.copy()
df_diet_copy = df_diet.copy()

# For df_population, make a copy with the first 3 columns
df_population_copy = df_population_copy.iloc[:, :3].copy()

# For df_renewable_energy_copy, make a copy with the first 3 columns
df_renewable_energy_copy = df_renewable_energy_copy.iloc[:, :4].copy()

# For df_gdp_copy, make a copy with the first 3 columns
df_gdp_copy = df_gdp_copy.iloc[:, :4].copy()

# For df_population, change column "Country name" to "Entity"
df_population_copy.rename(columns={'Country name': 'Entity'}, inplace=True)

# List of dataframes to process
dataframes = [df_population_copy, df_co2_copy, df_gdp_copy, df_energy_copy, df_fossil_energy_copy, df_renewable_energy_copy, df_education_copy, df_diet_copy]

# For all dataframes, delete column "Code" when it exists
for df_temp in dataframes:
    if 'Code' in df_temp.columns:
        df_temp.drop(columns=['Code'], inplace=True)

# For all dataframes, sort by 'Entity'
for df_temp in dataframes:
    if 'Entity' in df_temp.columns:
        df_temp.sort_values(by='Entity', inplace=True)

# Check the modified dataframes
display(df_population_copy.head())
display(df_co2_copy.head())
display(df_gdp_copy.head())
display(df_energy_copy.head())
display(df_fossil_energy_copy.head())
display(df_renewable_energy_copy.head())
display(df_education_copy.head())
display(df_diet_copy.head())
# Out:
#          Entity  Year  Population
# 0   Afghanistan  1950     7480464
# 51  Afghanistan  2001    19688634
# 50  Afghanistan  2000    19542986
# 49  Afghanistan  1999    19262854
# 48  Afghanistan  1998    18493134
#          Entity  Year  Annual CO₂ emissions (per capita)
# 0   Afghanistan  1949                           0.001992
# 53  Afghanistan  2002                           0.063856
# 52  Afghanistan  2001                           0.054300
# 51  Afghanistan  2000                           0.053581
# 50  Afghanistan  1999                           0.056671
#          Entity  Year  GDP per capita
# 0   Afghanistan  1950          1156.0
# 37  Afghanistan  1987          1211.0
# 38  Afghanistan  1988          1101.0
# 39  Afghanistan  1989           999.0
# 40  Afghanistan  1990           963.0
#          Entity  Year  Primary energy consumption per capita (kWh/person)
# 0   Afghanistan  1980                                          623.92865
# ...

# %% [markdown]
# ### Step 5 Combine data
# Make one dataframe copy with all data from the year 2000 on

# %%
# 20240618
# Filter dataframes to include only data from the year 2000 onwards
dfs = [df_population_copy, df_co2_copy, df_gdp_copy, df_energy_copy, df_fossil_energy_copy, df_renewable_energy_copy, df_education_copy, df_diet_copy]
dfs_filtered = [df[df['Year'] >= 2000] for df in dfs]

# Combine all dataframes on 'Entity' and 'Year' using inner join to keep only matching rows
combined_df = dfs_filtered[0]

for df_temp in dfs_filtered[1:]:
    combined_df = pd.merge(combined_df, df_temp, on=['Entity', 'Year'], how='inner')

# Replace null values with NaN (this step is not really necessary with inner join as there won't be any NaN values)
combined_df = combined_df.replace({None: np.nan})

# Remove the 'World' entity from the combined dataframe
combined_df = combined_df[combined_df['Entity'] != 'World']

# Sort the combined dataframe by 'Entity'
combined_df.sort_values(by='Entity', inplace=True)

# Check the combined dataframe
# print(combined_df.head())

# Define the new column names
new_column_names = {
    'Entity': 'Country',
    'Year': 'Year',
    'Population': 'Population',
    'Annual CO₂ emissions (per capita)': 'CO2 emission',
    'GDP per capita': 'GDP',
    'Primary energy consumption per capita (kWh/person)': 'Energy consumption',
    'Fossil fuels per capita (kWh)': 'Fossil Fuels',
    'Other renewables (including geothermal and biomass) electricity generation - TWh': 'Renewable energy',
    'Combined - average years of education for 15-64 years male and female youth and adults': 'Education',
    'Caloric supply': 'Caloric supply'
}

# Create a new DataFrame with the renamed columns
df_pred = combined_df.rename(columns=new_column_names)

# Print the renamed DataFrame
print(df_pred)

# Print the number of unique values in the 'Country' column
unique_entities = df_pred['Country'].nunique()
print(f"The 'Country' column has {unique_entities} unique values.")

# Get a list of all unique countries in the 'Country' column
unique_entities = df_pred['Country'].unique()

# Print the list of unique countries
print("List of unique countries in the database:")
print(unique_entities)
# Out:
#        Country  Year  Population  CO2 emission         GDP  \
# 0      Algeria  2000    30774624      2.774968   6834.5537
# 1      Algeria  2015    39543148      4.048425  14004.0000
# 2      Algeria  2010    35856348      3.300762  12587.7440
# 3      Algeria  2005    32956690      3.367830   9969.6230
# 4    Argentina  2000    37070772      3.851153  14368.9420
# ..         ...   ...         ...           ...         ...
# 229  Venezuela  2015    30529722      5.432513  18802.0000
# 230  Venezuela  2010    28715026      6.592949  17105.5800
# 227  Venezuela  2000    24427732      5.847243  13992.6080
# 228  Venezuela  2005    26668790      5.561206  14944.3400
# 231    Vietnam  2015    92191400      2.337115   5763.0000
#
#      Energy consumption  Fossil Fuels  Renewable energy  Education  \
# 0              9746.524     9741.3360          0.000000       6.06
# 1             15616.311    15601.1930          0.000000       7.55
# ...

# %% [markdown]
# ### Step 6 Clean data
# Only use countries and years where all data is available

# %% [markdown]
# ### Step 7 Make the graph
# Make a graph with x-axis year and y-axis percentage to first year we have in our table, in that way all data can be combined. The numbers itself do not matter, but the impact of increasing and decreasing numbers matter.
#
# Use a formula to group all countries and take the average value for each year for each column (CO2, Population, GDP,Fossil fuels, Renewable fuels, Education, Caloric supply)
#
# **Graph Description**
# How do GDP, fossil fuel and renewable energy usage, eduction and caloric supply correlate with CO2 emissions per capita for 10 different countries.
#
# **Graph Axis**
# * xlabel: Year
# * ylabel: Percentage starting all at 100% and use a logaritmic scale to visualize the different orders of data magnitude
#
# ** Graph Values**
# * CO2 emission: red, barplot
# * Energy consumption: yellow, barplot
# * GDP: blue, plot
# * Fossil fuels: black, plot
# * Renewable energy: green, plot
# * Education: orange, plot
# * Caloric supply: purple, plot
# * Energy consumption: pink, plot

# %% [markdown]
# #### First graph
# The first graph I made I found out that the line following the CO2 emission most similar, should be the most predictive and therefore has the most impact.
#
# #### Second graph
# Then I decided to make a new graph where I divided each variable by the 'CO2 emission' for each year to show the relative impact.

# %%
# FIRST GRAPH

import matplotlib.pyplot as plt

# Drop the 'country' column
df_pred_no_country = df_pred.drop(columns=['Country'])

# Group by year and calculate the average for each year
df_avg = df_pred_no_country.groupby('Year').mean()

# Calculate the percentage relative to the first year
df_percentage = df_avg.div(df_avg.iloc[0]).mul(100)

# Plot the data
plt.figure(figsize=(14, 8))

# Bar plot for CO2 emission
plt.bar(df_percentage.index, df_percentage['CO2 emission'], color='red', alpha=0.5, label='CO2 emission')

# Line plots for other variables
plt.plot(df_percentage.index, df_percentage['GDP'], color='blue', marker='o', label='GDP')
plt.plot(df_percentage.index, df_percentage['Fossil Fuels'], color='black', marker='o', label='Fossil Fuels')
plt.plot(df_percentage.index, df_percentage['Renewable energy'], color='green', marker='o', label='Renewable energy')
plt.plot(df_percentage.index, df_percentage['Education'], color='orange', marker='o', label='Education')
plt.plot(df_percentage.index, df_percentage['Caloric supply'], color='purple', marker='o', label='Caloric supply')
plt.plot(df_percentage.index, df_percentage['Energy consumption'], color='yellow', marker='o', label='Energy consumption')

# Set y-axis to logarithmic scale
plt.yscale('log')

# Graph description and labels
plt.xlabel('Year')
plt.ylabel('Percentage starting all at 100% (Log Scale)')
plt.title('Correlation of Various Factors with CO2 Emissions Over Time')
plt.legend()

# Show the plot
plt.show()

# %%
# SECOND GRAPH
import matplotlib.pyplot as plt

# Drop the 'Country' column
df_pred_no_country = df_pred.drop(columns=['Country'])

# Group by year and calculate the average for each year
df_avg = df_pred_no_country.groupby('Year').mean()

# Calculate the percentage relative to the first year
df_percentage = df_avg.div(df_avg.iloc[0]).mul(100)

# Divide each variable by CO2 emission
df_relative = df_percentage.div(df_percentage['CO2 emission'], axis=0)

# Plot the data
plt.figure(figsize=(14, 8))

# Bar plot for Energy consumption
plt.bar(df_relative.index, df_relative['Energy consumption'], color='yellow', alpha=0.5, label='Energy consumption')

# Line plots for other variables
plt.plot(df_relative.index, df_relative['GDP'], color='blue', marker='o', label='GDP')
plt.plot(df_relative.index, df_relative['Fossil Fuels'], color='black', marker='o', label='Fossil Fuels')
plt.plot(df_relative.index, df_relative['Renewable energy'], color='green', marker='o', label='Renewable energy')
plt.plot(df_relative.index, df_relative['Education'], color='orange', marker='o', label='Education')
plt.plot(df_relative.index, df_relative['Caloric supply'], color='purple', marker='o', label='Caloric supply')

# Set y-axis to logarithmic scale
plt.yscale('log')

# Graph description and labels
plt.xlabel('Year')
plt.ylabel('Logarithmic Scale (Relative to CO2 Emission)')
plt.title('How GDP, Fossil Fuel and Renewable Energy Usage, Education, and Caloric Supply are related to CO2 Emissions Per Capita for 68 Different Countries')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Step 8 Conclusion
# The biggest predictor of CO2 output is the use of fossil fuels as it is most constant relative to the CO2 emission.

# %% [markdown]
# ## Final assignment - 2. Biggest strides in decreasing CO2 output
# Which countries are making the biggest strides in decreasing CO2 output?

# %% [markdown]
# ### Guideline
# You'll need to find the relative CO2 output for each country to be able to calculate this. But countries can have growing and shrinking populations too, so it's probably a good idea to take this into account as well.

# %% [markdown]
# ### Step 1 Define data
# To define which country makes the biggest strides in decreasing CO2 output, I have to calculate the relative decrease in CO2 emissions over time for each country and identify the country with the highest percentage decrease. As I already use the CO2 emission per capita data, it will be relative to the population as well.

# %%
import pandas as pd

# Use the df_pred DataFrame from the first assigment
# Calculate the average CO2 emission for each country
df_avg_country = df_pred.groupby(['Country', 'Year']).mean().reset_index()

# %% [markdown]
# ### Step 2 Combine data
# Use a pivot table to get years as columns and countries as rows from the dataset from Final Assigment - 1.

# %%
# Pivot the DataFrame to get years as columns and countries as rows
df_pivot = df_avg_country.pivot(index='Country', columns='Year', values='CO2 emission')

# Calculate the percentage change from the first to the last year for each country
df_pivot['Percentage Change'] = (df_pivot[df_pivot.columns[-1]] - df_pivot[df_pivot.columns[0]]) / df_pivot[df_pivot.columns[0]] * 100

# Sort countries by the percentage change
df_sorted = df_pivot.sort_values(by='Percentage Change')

# %%
# Print the country with the biggest decrease in CO2 emissions
country_with_biggest_decrease = df_sorted.index[0]
percentage_decrease = df_sorted.iloc[0]['Percentage Change']

print(f"The country with the biggest decrease in CO2 emissions is {country_with_biggest_decrease} with a decrease of {percentage_decrease:.2f}%.")
# Out:
# The country with the biggest decrease in CO2 emissions is Denmark with a decrease of -39.19%.

# %% [markdown]
# ### Step 3 Make a graph

# %%
# Remove entities with no value in Percentage Change
df_pivot = df_pivot.dropna(subset=['Percentage Change'])

# Sort countries by the percentage change in descending order
df_sorted = df_pivot.sort_values(by='Percentage Change', ascending=False)

# Plot the data
plt.figure(figsize=(14, 8))
plt.barh(df_sorted.index, df_sorted['Percentage Change'], color='skyblue')

# Reverse the x-axis
plt.gca().invert_xaxis()

plt.xlabel('Percentage Change in CO2 Emissions')
plt.ylabel('Country')
plt.title('Countries with Highest Decrease in CO2 Emissions Percentage')
plt.grid(axis='x')

# Show the plot
plt.show()

# %% [markdown]
# #### Step 4 Conclusion
# The country with the biggest decrease in CO2 emissions is Denmark with a decrease of -39.19%.

# %% [markdown]
# ## Final assignment - 3. Best future price for non-fossil fuel energy
# Which non-fossil fuel energy technology will have the best price in the future?

# %% [markdown]
# ### Guideline
# To be able to predict prices you'll probably need to use linear regression over the various non-fossil fuel options.

# %% [markdown]
# ### Step 1 Research

# %% [markdown]
# Start by going to ["Our World in Data" webpage](https://ourworldindata.org/) and feel free to use any dataset that you can find.

# %% [markdown]
# Predicting future prices of non-fossil fuel energy accurately requires consideration of various factors such as technological advancements, market demand, policy changes, and economic conditions.
#
# Starting with linear regression is useful for analyzing historical price trends and making rough predictions about future prices based on those trends.
#
# **Data Collection**
#
# In this research I will gather historical price data for various energy technologies and shows the average cost per unit of energy generated across the lifetime of a new power plant. This data is expressed in US dollars per kilowatt-hour. It is adjusted for inflation but does not account for differences in
# the cost of living between countries.
#
# This graph includes prices of:
#
# **Solar panels**
# Solar panels, named photovoltaics in my research, use the power of the sun.
#
# **Wind turbines**
# Wind turbines use the power of wind. For this research I only have data of windturbine costs for Denmark.
#
# **Geothermal electricity**
# Geothermal electricity is generated from geothermal energy.
#
# **Concentrating solar**
# By using mirrors to concentrate sunlight into one spot, generating heat to be used as energy to feed heat engines or thermal reactions generating electricity.

# %% [markdown]
# ### Step 2 Define data
# All data from the "Our World in Data" webpage: [Costs of 66 different technologies over time"](https://ourworldindata.org/grapher/costs-of-66-different-technologies-over-time)
#
# #### Costs of different technologies
# What is the cost of different technologies over time?
#
# **File**
#
# costs-of-66-different-technologies-over-time.csv
#
# **Source population**
#
# Farmer and Lafond (2016) – with minor processing by Our World in Data. “The cost of 66 different technologies over time” [dataset]. Farmer and Lafond, “How predictable is technological progress?” [original data]. Retrieved June 18, 2024 from https://ourworldindata.org/grapher/costs-of-66-different-technologies-over-time

# %% [markdown]
# ### Step 3 Data Preprocessing
# * Load the required libraries and the dataset from the specified path.
# * Filter the dataset to include only the specified entities and years from 1981 onwards.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
file_path = '/content/drive/MyDrive/Colab Notebooks/Winc Final Assigment - Data analysis in Python - Pepijn van Schijndel/Datasets/costs-of-66-different-technologies-over-time.csv'
df = pd.read_csv(file_path)

# Filter the dataframe for the specific entities
entities = ['Concentrating solar', 'Geothermal electricity', 'Photovoltaics', 'Wind turbine (Denmark)']
df_filtered = df[df['Entity'].isin(entities)]

# Further filter the data to include only years from 1981 onwards
df_filtered = df_filtered[df_filtered['Year'] >= 1981]

# %% [markdown]
# ### Step 4 Train a Linear Regression Model for Each Entity
# * For each energy type, prepare the data, train a linear regression model using the 'Technology cost' column, and calculate evaluation metrics (Mean Squared Error and R² Score).
# * Get the last year of data for each entity and generate future year predictions from the year after the last known year until 2026.
# * Clip the predicted prices to ensure no values drop below zero.
# * Store the minimum predicted future cost for each entity.

# %%
models = {}
predictions = {}
min_future_costs = {}

# Define a color map for consistent coloring
colors = plt.get_cmap('tab10')

# Prepare data for linear regression and train a model for each energy type
for entity in entities:
    entity_data = df_filtered[df_filtered['Entity'] == entity]
    X = entity_data[['Year']].values
    y = entity_data['Technology cost'].values

    model = LinearRegression()
    model.fit(X, y)

    # Store the model
    models[entity] = model

    # Predict on the historical data
    y_pred = model.predict(X)

    # Calculate metrics
    mse = mean_squared_error(y, y_pred)
    r2 = r2_score(y, y_pred)
    print(f'{entity}: Mean Squared Error: {mse}, R^2 Score: {r2}')

    # Get the last year in the data for this entity
    last_year = entity_data['Year'].max()

    # Predict future prices starting from the year after the last known year
    future_years = np.array([[year] for year in range(last_year + 1, 2027)])
    future_prices = model.predict(future_years)

    # Ensure no negative prices
    future_prices = np.clip(future_prices, a_min=0, a_max=None)

    # Store the predictions
    predictions[entity] = (future_years.flatten(), future_prices)

    # Find the minimum future cost for this entity
    min_future_costs[entity] = future_prices.min()
# Out:
# Concentrating solar: Mean Squared Error: 70.25311553888054, R^2 Score: 0.5985008726405803
# Geothermal electricity: Mean Squared Error: 0.29222328264584396, R^2 Score: 0.9495108929161138
# Photovoltaics: Mean Squared Error: 2.1572134087698935, R^2 Score: 0.8989890358654677
# Wind turbine (Denmark): Mean Squared Error: 275405.10327067674, R^2 Score: 0.9271968141396296

# %% [markdown]
# ### Step 5 Visualize the Predictions
# Use a consistent color map to plot both historical prices and predicted future prices for each entity on the same graph to compare and visualize trends.

# %%
plt.figure(figsize=(12, 8))

# Plot historical prices and future predictions with consistent colors
for i, entity in enumerate(entities):
    entity_data = df_filtered[df_filtered['Entity'] == entity]
    color = colors(i)
    plt.plot(entity_data['Year'], entity_data['Technology cost'], marker='o', label=f'Historical {entity}', color=color)
    future_years, future_prices = predictions[entity]
    plt.plot(future_years, future_prices, marker='x', linestyle='--', label=f'Predicted {entity}', color=color)

plt.xlabel('Year')
plt.ylabel('Technology cost')
plt.yscale('log')  # Use logarithmic scale for better visualization
plt.title('Energy Price Trends and Predictions')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 6 Determine the Cheapest Entity in the Future
# Find the entity with the minimum predicted future cost and print the result.

# %%
# Find the entity with the minimum predicted future cost
cheapest_entity = min(min_future_costs, key=min_future_costs.get)
cheapest_cost = min_future_costs[cheapest_entity]

print(f'The cheapest entity in the future is {cheapest_entity} with a predicted cost of {cheapest_cost} USD per kWh.')
# Out:
# The cheapest entity in the future is Concentrating solar with a predicted cost of 0.0 USD per kWh.
